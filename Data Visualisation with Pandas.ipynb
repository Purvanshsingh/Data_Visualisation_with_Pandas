# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
# Here We have Generate Random data for visualization
df = pd.DataFrame(randn(1000), index = pd.date_range('2020-05-08', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2020-05-08', periods = 1000))
df.head()
# Out:
#                value
# 2020-05-08  1.264773
# 2020-05-09 -0.739621
# 2020-05-10 -0.738885
# 2020-05-11 -1.240326
# 2020-05-12  0.462214

# %%
df['value'] = df['value'].cumsum() # it will will give cumilative sum value n = n-1 + n - 2
df.head()
# Out:
#                value
# 2020-05-08  1.264773
# 2020-05-09  0.525152
# 2020-05-10 -0.213733
# 2020-05-11 -1.454059
# 2020-05-12 -0.991845

# %%
# it will plot line polt
df.plot()

# %%
df.plot(figsize = (20,10)) # figsize will change the size of the plot

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2020-05-08   -0.003161
# 2020-05-09    0.401105
# 2020-05-10    2.043207
# 2020-05-11    2.788020
# 2020-05-12    3.486410
# Freq: D, dtype: float64

# %%
print(type(df))
print(type(ts))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
pd.DataFrame.plot?

# %%
ts.plot(figsize=(10,5)) # Plotting series

# %%
# plotting using matplotlib.pyplot.plot method
plt.plot(ts)

# %%
# Loding Iris Dataset from Seaborn
iris = sns.load_dataset('iris')
print("We have these species in our dataset",list(iris['species'].unique()))
iris.head()
# Out:
# We have these species in our dataset ['setosa', 'versicolor', 'virginica']
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# by default plot method will make line plot
ax = iris.plot(figsize = (15,5))
print(type(ax))
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_title('Iris DataSet')
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# Text(0.5, 1.0, 'Iris DataSet')

# %%
# We can plot multiple types of plots using kind parameter.
ts.plot(kind = 'bar')

# %%
# histogram always shows frequency
iris.plot(kind = 'hist')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot()

# %%
df.iloc[0].plot(kind='pie')

# %%
# another way to make bar plot using plot.bar() method
df.iloc[0].plot.bar()

# %%
# Loading titanic DataSet
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar')

# %%
# Crearting Random DataFrame with 10 rows and 4 columns
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.930001  0.831518 -0.395598  0.105309
# 1  0.846671 -1.448477  0.186287  1.968851
# 2 -0.603073 -0.171823  2.440440  0.949216
# 3  0.151436 -0.009000 -0.406532 -0.116510
# 4  0.633862  0.097683 -0.782263  1.318022
# 5 -1.086347 -1.419359  0.771073  1.427059
# 6 -0.466007 -1.110125  0.803472 -1.011228
# 7  0.301585  0.045665  0.559256  0.290961
# 8  0.261890  0.539285  0.161247  0.611655
# 9  0.723307  1.662154 -1.776631  0.488414

# %%
# indexes will be represented on X axis
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
# Horizontal Bar plot
df.plot.barh()

# %%
# in x axis it will showing us range and in y axis it is showing frequency
# it always talks about the frequency
iris.plot.hist()

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = True, bins = 100)

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100)

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.hist(color = 'orange', alpha = 0.9, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001ECFBB51608>,
# ...
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
# Scatter plot is used to study relation between two variables
df.plot.scatter(x = 'sepal_length', y = 'petal_length')

# %%
# we have just add a contrast column which will control tha colour of data points
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
ax = df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length')
ax1 =df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width',ax=ax, color = 'g')
df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width',ax=ax1, color = 'r')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 15, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
# m equal to sum of all data
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (15, 5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ECFFD0F708>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 16, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC85C3AF88>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'g--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (15,5), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True,figsize=(5,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001EC85882D08>,
# ...
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,2), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-137-af09896ed1db> in <module>
# ----> 1 from descartes import PolygonPatch
#
# ModuleNotFoundError: No module named 'descartes'

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
